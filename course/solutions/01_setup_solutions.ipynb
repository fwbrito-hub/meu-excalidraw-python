# %% [markdown]
# # ✅ Solução: Lição 01 - Healthcheck
#
# Abaixo está a implementação correta da rota de saúde. Note como usamos um dicionário Python simples que o FastAPI converte automaticamente para JSON.

# %%
from fastapi import FastAPI

app = FastAPI()

@app.get("/api/saude")
async def checar_saude():
    return {"status": "operacional", "versao": "1.0.0"}
