# %% [markdown]
# # ✅ Solução: Lição 02 - DB & Migrations
#
# Para gerar a migração automática após alterar seu modelo no `database.py`, o comando é:
#
# ```bash
# alembic revision --autogenerate -m "adiciona descricao ao projeto"
# ```
#
# E para aplicar a mudança no banco:
# ```bash
# alembic upgrade head
# ```

# %%
comando_alembic = "alembic revision --autogenerate -m 'adiciona descricao ao projeto'"
print(f"Solução correta: {comando_alembic}")
