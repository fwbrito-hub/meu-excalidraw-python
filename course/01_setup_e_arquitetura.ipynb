# %% [markdown]
# # 🚀 Lição 01: Setup e Arquitetura do SaaS Elite
#
# Nesta aula, vamos preparar seu ambiente de combate e entender por que escolhemos o **FastAPI** como o coração do nosso SaaS.
#
# ## 1. Preparando o Terreno
# Antes de codar, certifique-se de ter rodado o script de bootstrap na pasta raiz:
# ```bash
# python bootstrap_course.py
# ```
#
# ## 2. O Desafio: Healthcheck
# Um sistema profissional precisa de uma rota de 'Saúde' para que monitores de carga (como o Docker ou AWS) saibam que ele está vivo.
#
# ### Seu Desafio:
# Complete o código abaixo para criar a rota `/api/saude`.
#
# > **Dica:** A resposta está em `course/solutions/01_setup_solutions.ipynb` se precisar de ajuda!

# %%
from fastapi import FastAPI

app = FastAPI()

# EXERCÍCIO: Complete a função abaixo para retornar um JSON com {'status': 'operacional'}
@app.get("/api/saude")
async def checar_saude():
    # ??? -- Digite seu retorno aqui
    return {"mensagem": "Complete o exercicio!"}
