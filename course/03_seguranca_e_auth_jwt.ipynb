# %% [markdown]
# # 🔒 Lição 03: Segurança e Multi-tenancy (JWT)
#
# Um SaaS profissional não guarda apenas dados; ele guarda **segredos**.
#
# ## 1. O que é o JWT?
# Imagine um crachá digital que diz quem você é e o que pode fazer. O servidor assina esse crachá para que ninguém possa falsificá-lo.
#
# ## 2. O Desafio: Proteção de Dados
# Queremos garantir que apenas usuários logados possam deletar projetos.
#
# ### Seu Desafio:
# Complete o código da rota de deleção abaixo para que ela use a dependência de segurança que criamos no projeto.
#
# > **Dica:** Procure pela função `get_current_user` no arquivo `backend/app/main.py`.

# %%
from fastapi import Depends
# EXERCÍCIO: Importe e use a dependência correta para proteger esta rota

@app.delete("/api/projetos/{id}")
async def deletar_projeto(id: int, user = Depends(???)): # O que vai no lugar dos ???
    return {"msg": f"Projeto {id} deletado pelo usuario {user.username}"}
