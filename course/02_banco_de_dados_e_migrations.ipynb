# %% [markdown]
# # 🗄️ Lição 02: O Poder das Migrations (Alembic)
#
# No mundo real, o banco de dados evolui. Adicionamos campos, mudamos tipos e corrigimos erros.
#
# ## 1. Por que não deletar o banco?
# Deletar o banco de dados em produção é um pecado mortal. Você perde dados de clientes reais. Usamos **Migrations** para 'contar uma história' ao banco sobre o que mudou.
#
# ## 2. O Desafio: Expandindo o SaaS
# Nossos usuários querem adicionar uma **descrição** aos seus desenhos.
#
# ### Seu Desafio:
# 1. Abra o arquivo `backend/app/database.py`.
# 2. Adicione a coluna `descricao` na classe `Projeto`.
# 3. Tente completar o comando do Alembic abaixo para gerar a migração.
#
# > **Dica:** O comando começa com `alembic revision --autogenerate -m "nome_da_migracao"`.

# %%
# EXERCÍCIO: Qual o comando você digitaria no terminal para gerar a migração automática?
# Substitua o comentário abaixo pelo comando correto

comando_alembic = "???" # Digite aqui o comando

print(f"Você executará: {comando_alembic}")
